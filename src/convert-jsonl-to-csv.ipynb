# %%
import json
import pandas as pd

# %%
data = []
with open("../data/data_v3.jsonl", encoding="utf-8") as f:
    for line in f:
        data.append(json.loads(line))

df = pd.DataFrame(data)

# %%
df.to_csv("../data/data_v3.csv")
